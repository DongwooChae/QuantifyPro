# %%
import pandas as pd

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
names = summer.loc[:9, "Athlete"].copy()

# %%
names
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 2        DRIVAS, Dimitrios
# 3       MALOKINIS, Ioannis
# 4       CHASAPIS, Spiridon
# 5    CHOROPHAS, Efstathios
# 6            HAJOS, Alfred
# 7         ANDREOU, Joannis
# 8    CHOROPHAS, Efstathios
# 9            NEUMANN, Paul
# Name: Athlete, dtype: object

# %%
names.str.lower()
# Out:
# 0            hajos, alfred
# 1         herschmann, otto
# 2        drivas, dimitrios
# 3       malokinis, ioannis
# 4       chasapis, spiridon
# 5    chorophas, efstathios
# 6            hajos, alfred
# 7         andreou, joannis
# 8    chorophas, efstathios
# 9            neumann, paul
# Name: Athlete, dtype: object

# %%
# 이게 뭐지?? >> 첫 번째 글자만 대문자로 변환!
names.str.title()
# Out:
# 0            Hajos, Alfred
# 1         Herschmann, Otto
# 2        Drivas, Dimitrios
# 3       Malokinis, Ioannis
# 4       Chasapis, Spiridon
# 5    Chorophas, Efstathios
# 6            Hajos, Alfred
# 7         Andreou, Joannis
# 8    Chorophas, Efstathios
# 9            Neumann, Paul
# Name: Athlete, dtype: object

# %%
# 이거 뭐지?? >> summer라는 변수에서 >> Event라는 열을 찾고, str 문자열을 정한 다음,.. split?
summer.Event.str.split(" ", n=2, expand=True)
# 공백을 기준으로 나누기!
# expand를 하면 텍스트 나누기가 됨, 별도의 열에 입력된다!
# Out:
#           0          1            2
# 0      100M  Freestyle         None
# 1      100M  Freestyle         None
# 2      100M  Freestyle  For Sailors
# 3      100M  Freestyle  For Sailors
# 4      100M  Freestyle  For Sailors
# ...     ...        ...          ...
# 31160    Wg         84           KG
# 31161    Wg         96           KG
# 31162    Wg         96           KG
# 31163    Wg         96           KG
# 31164    Wg         96           KG
#
# [31165 rows x 3 columns]

# %%
# 해당 열 내에 특정 단어를 찾고, 불리언 값을 추출하는 건가?
summer.Event.str.contains("100M")
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Name: Event, Length: 31165, dtype: bool

# %%
summer[summer.Event.str.contains("100M")]
# 이걸 이용하면,.. 특정 열에 특정 단어가 포함된 것만 추출할 수 있음!
# 불리언 시리즈로 반환하려면 ,.. 대괄호 빼고 그냥 쓰면 됨 주르륵..!
# 만약 조건이 여러개라면..? 변수를 만들고 그 안에 변수를 또 다시 조건을 추가해서 만들고.. 이래야 하나?
# Out:
#        Year    City      Sport Discipline               Athlete Country  \
# 0      1896  Athens   Aquatics   Swimming         HAJOS, Alfred     HUN
# 1      1896  Athens   Aquatics   Swimming      HERSCHMANN, Otto     AUT
# 2      1896  Athens   Aquatics   Swimming     DRIVAS, Dimitrios     GRE
# 3      1896  Athens   Aquatics   Swimming    MALOKINIS, Ioannis     GRE
# 4      1896  Athens   Aquatics   Swimming    CHASAPIS, Spiridon     GRE
# ...     ...     ...        ...        ...                   ...     ...
# 29660  2012  London  Athletics  Athletics       STEWART, Kerron     JAM
# 29661  2012  London  Athletics  Athletics  BRYZGINA, Yelyzaveta     UKR
# 29662  2012  London  Athletics  Athletics          POVH, Olesya     UKR
# 29663  2012  London  Athletics  Athletics       RYEMYEN, Mariya     UKR
# 29664  2012  London  Athletics  Athletics        STUY, Hrystyna     UKR
#
#       Gender                       Event   Medal
# 0        Men              100M Freestyle    Gold
# ...

# %% [markdown]
# # 여기서부터는 시각화!

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
titanic.plot(subplots=True,figsize=(15, 12), sharex=True

)
plt.show()

# %%
titanic.plot(subplots=True,figsize=(15, 12), sharex=False, sharey=False

)
plt.show()
# sharey = true로 설정하면, 모든 서브플롯의 y축이 동일한 눈금으로 바뀌게 됨!
# fare열의 눈금이 가장 크므로, sharey는 이 fare열의 단위를 사용하게 됨
# 만약 age 처럼 특정한 열만 보고 싶다면?!

# %%
xticks = [x for x in range(0,901,50)]
yticks = [y for y in range(0,81,5)]

titanic.age.plot(figsize=(12,8))
plt.show()

# %% [markdown]
# # customization

# %%
xticks = [x for x in range(0,901,50)]
yticks = [y for y in range(0,81,5)]

titanic.age.plot(figsize=(12,8), fontsize= 13, c= "r", linestyle = "-", xlim=(0,900), ylim=(0,80),
                 xticks=xticks, yticks=yticks, rot=45)
plt.title("Titanic - Ages", fontsize = 15)
plt.legend()
plt.xlabel("Passenger No", fontsize = 11)
plt.ylabel("Age", fontsize = 11)
plt.grid()
plt.show()

# plt.style.available
# plt.style.use("grayscale")
